# %% [markdown]
# # Test bed

# %%
from termcolor import colored
from dotenv import load_dotenv

# Setup OpenAI API key 
load_dotenv()

# %%
document_to_summarize = \
"""
댓글 읽어보기는 아주 간단합니다. 최동석 님, 강의 좋습니다. 도 탐사의 요즘에 강진구 기자에 대해서 다시 분석해 주시면 감사드리겠습니다. 얼마 전에 강진구 기자에 대한 분석이 있었는데, 굉장히 훌륭한 기자라는 거죠. 아주 유능한 기자다 하는 걸 제가 알려드리고 그랬는데 그거를 요즘 강진구 기자가 여기저기서 비판과 비난을 많이 받고 있는 모양입니다. 그래서 이렇게 다시 분석해 주시면 좋겠다고 그래서 좀 들여다봤어요. 들여다봤더니 왜 그런지는 대충 알아요. 정확한 내용은 내가 잘 모르지만 정확한 내용을 뭐 알아도 거기서 거깁니다. 바빌론의 강가 감사합니다. 교수님, 정치가 모두 부패된 기분입니다. 맞습니다. 정치가 부패했기 때문에 온 나라가 억압과 착취가 가능한 상태가 됐습니다. 문제조심, 아주 심각한 문제입니다. 그래서 인사조심 문자로서 이거를 아주 밝히 밝혀주어서 설명 드려야 우리가 지금 착취를 당하고 있구나 하는 걸 알 수 있게 되죠. 착취하는 유형이 여러 가지인데 오늘은 한두 가지 정도 알려드리고 또 다음에 계속 이어가겠습니다. 이 분의 의도는 정확하게 모르겠습니다. 이렇게 단 문으로 써주셔서 그런데 제가 대강 보기에 내용은 정확하게 모릅니다. 강진국 기자나 박대원 기자가 더 탐사해서 어떤 일이 어떻게 벌어졌다는 것만 대강만 알지 자세한 내용은 잘 모릅니다. 그러나 모든 사람은 자신이 타고난 재능에 의해 직무 활동의 결과가 뭐죠 사회적 성충죠. 그 결과를 만들어내야 합니다. 그 결과를 만들어내면 사람은 유능한 것이고 그 결과를 만들어내지 못하면 무능한 것입니다. 그것 이상을 바라면 안 됩니다. 무슨 말이냐

함부로 도독성이나 윤류의식일 그 사람의 도독성 윤류의식 뭐 어쩌고 이런 걸 얘기하면 안 된다. 그 말입니다. 왜 냐면 타인에 대하여 의도적이거나 의도적이 아니거나 학교지거나 착취하는 것이 아니라면 우리 각자는 언제나 직무의 성과에 대해 평가할 수 있어야 합니다. 자기 자신이 한 성과에 대해서 평가할 수 있어야 되고 다른 사람이 공적인 직무에 있는 사람이란 것은 사실상 공적인 직무이다. 국민의 알궏리를 대신해서 취재해서 알려주는 거니까요. 그러니까 공적인 직무에 있는 사람들이라고 할 수 있죠. 그러니까 입법, 사법, 행정, 언론에 딱 하나 가지 언론이라는 제3의 권력기관이 있는 거죠. 언론사 여기가 제대로 되어 있으면 국가가 제대로 쓰는 거고 그렇지 않으면 문제가 심각하죠. 우리나라의 문제가 심각한 이유는 바로 언론이 죽었기 때문이죠. 그 죽은 언론마저 윤석열은 다 잡아먹으려고 지금 끼룩거리고 있는 거죠. 이동관을 통해서 그러니까 우리 각자는 언제나 그 사람이 맡고 있는 직무의 성과에 대해 평가할 수 있어야 됩니다. 그래서 기자들은 사실은 공적인 직무라고 말할 수 없지만 사실은 공적인 일을 하고 있어서 저는 공적인 직무를 맡은 사람들이라고 생각합니다. 기자라면 기자 타이틀을 자기가 
 되는 것이고 김은경 위원장 님은 상처받으면서도 명작을 만들었습니다. 그렇습니다. 내가 내가 그래서 김은경을 칭찬해 주고 싶은 거예요. 처음에는 내가 굉장히 비판적인 입장을 가졌다가 결과를 낸 걸 보고 내가 내가 기억했구나 이렇게 생각 한 거예요. 고질범 51이라는 짧은 기간 동안에 그런 작품을 만들어냈다니 이게 제대로 잘 받아들이기만 하면 민주당은 살아날 것이고 이게 안 받아들리면 민주당은 이제 나라구로 가는 거예요. 그래서 내가 계속 민주당을 생각하면서 계속 이 강의를 하는 겁니다. 행복블루님, 감사합니다. 네, 저도 그렇습니다. 명작을 만들어냈습니다. 이 정도면 충분히 합격점을 줄 수 있습니다. 그래서 오늘도 조금 그 얘기를 하고 부족한 남는 부분은 뭐입니까? 다음 시간에 또 조직론과 함께 같이 공부해 가도록 하겠습니다. 제트환님, 지지환님, 두찬용진, 두찬용진,
제가 잘 모르겠습니다. 들은 자신들의 잘못된 사실 행위는 숨기고 난만 공격하는 나쁜 인간들임. 두찬용진들은 누군지 잘 모르겠습니다.
"""

# %%
from langchain import PromptTemplate
from langchain.chains import LLMChain
from langchain.chat_models import ChatOpenAI
from langchain.docstore.document import Document
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains.combine_documents.stuff import StuffDocumentsChain
from langchain.chains.combine_documents.reduce import ReduceDocumentsChain
from langchain.chains.combine_documents.reduce import ReduceDocumentsChain
from langchain.chains.combine_documents.map_reduce import MapReduceDocumentsChain


def clean_up_sentence_punctuation_and_fix_errors( text:str, chunk_size = 1000, max_token:int=3000, model:str="gpt-3.5-turbo", language:str="ko", verbose:bool = False )->str:

    llm = ChatOpenAI(temperature=0.0, model_name=model)

    # Setup Map process
    correct_template = PromptTemplate.from_template("""
    아래 문장의 문장부호를 다 정리해줘. 그리고 소리나는대로 잘못 적은 단어를 고쳐줘. 내용상 나뉘어야 하면 줄바꿈도 해줘.  고유명사 틀린것도 수정하고, 수정한 글은 일반 텍스트로 적어줘. 그리고 아래 예제처럼 자주 틀리는 것들이 있으니 참고해서 수정해줘. 
                                                    
    강진국 -> 강진구
    박대원 -> 박대용
    도독성 -> 도덕성
    윤류의식 -> 윤리의식 
    알궏리를 -> 알권리를
    어갑하고 착취하도록 -> 억압하고 착취하도록
    일어쿽 저러고 -> 이러쿵 저러쿵
    홍의 -> 혼외
    나라구 -> 나락
    도 탐사 -> 더탐사
    개몽 -> 계몽
    성충죠 -> 성취죠
    석진 위원장 -> 혁신 위원장
    성취혜층 모형 -> 성취예측모형
    강준규 -> 강진구
    홍의 자식 -> 혼외자식
    고질범 51이라는 -> 고작 51일이라는
    -------
    {docs}

    수정된 문서:""")



    # Create docs from text
    docs = Document( page_content=text, metadata={"source":"local"} )

    # Split text
    text_splitter = CharacterTextSplitter(
        chunk_size = chunk_size,
        chunk_overlap  = 0
    )

    splited_docs = text_splitter.split_documents([docs])

    # Run chain
    merged_document = ""
    for doc in splited_docs:
        chain = LLMChain(llm=llm,prompt=correct_template, verbose=verbose)        
        corrected_doc = chain.run(doc.page_content)
        merged_document += corrected_doc
        merged_document += '\n\n'

    return merged_document

# %%
rectified_docs = clean_up_sentence_punctuation_and_fix_errors(document_to_summarize, chunk_size = 1000, verbose=True)
print(rectified_docs)
